# %% [markdown]
# ## Imports

# %%
# File
import pathlib

# %%
# Data
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Charting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Deep Learning
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, MaxPool1D, Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from keras.optimizers import Adam, RMSprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preprocessing functions

# %%
def walk_forward(df, x_labels, y_labels, n, n_input_labels, 
                 split_per=None, split_data=False, y_offset=0):
    
    td_shape = df.shape
    td_l = td_shape[0]
    
    x_indices = [range(i, i+n) for i in range(td_l-n)]
    y_indices = [range(i+y_offset, i+n) for i in range(td_l-n)]
    
    x = df.loc[:, x_labels].values[x_indices]
    y = df.loc[:, y_labels].values[y_indices]
    
    if split_data:
        split_index = int(len(x)*split_per)
        x = x.reshape(-1, n, n_input_labels, 1)
        y = y.reshape(-1, n-y_offset)
        X_train, X_test, y_train, y_test = (x[:split_index], x[split_index:], y[:split_index], y[split_index:])
        return X_train, X_test, y_train, y_test
    
    return x, y

# %%
def batch_sequence_split(df, x_labels, y_labels, n, n_input_labels, split_index):
    
    X_train = df[x_labels].iloc[:split_index].values.reshape(-1, n, n_input_labels, 1)
    X_test = df[x_labels].iloc[split_index:].values.reshape(-1, n, n_input_labels, 1)
    y_train = df[y_labels].iloc[:split_index].values.reshape(-1, n)
    y_test = df[y_labels].iloc[split_index:].values.reshape(-1, n)
    
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Get Data

# %%
train_df = pd.read_pickle('./data/train_df.pkl')

# %%
train_10noise_df = (pd.read_pickle('./data/10per_noise_train_df.pkl'))

# %%
train_df = train_10noise_df.iloc[:100000, :]

# %%
train_df.head()
# Out:
#    acc_10noise  vel_10noise  exc_10noise  disp_10noise
# 0     0.535463     0.500001     0.537666      0.500069
# 1     0.477690     0.504961     0.475392      0.500196
# 2     0.549265     0.512874     0.536868      0.500836
# 3     0.544417     0.546960     0.538491      0.502288
# 4     0.456147     0.541011     0.461039      0.504688

# %%
train_df.loc[:200, :].plot()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Some config params

# %%
td_shape = train_df.shape
td_l = td_shape[0]

# %%
x_labels = ['exc_10noise', 'acc_10noise', 'vel_10noise']
y_labels = ['disp_10noise']

# %%
n = 500
n_input_labels = len(x_labels)
y_offset = 250

# %%
train_percentage = 0.7
length_train_data = len(train_df)
split_index = int(length_train_data*train_percentage)

# %%
split_index
# Out:
# 70000

# %% [markdown]
# ## Get train and test data

# %% [markdown]
# ### Walk forward

# %%
X_train, X_test, y_train, y_test = walk_forward(train_df, 
                                                x_labels, y_labels, 
                                                n, n_input_labels, y_offset=y_offset,
                                                split_per=0.7, split_data=True)

# X_train = X_train.reshape(-1, n, n_input_labels, 1)
# y_train = y_train.reshape(-1, n-y_offset)

# X_test = train_df[x_labels].iloc[split_index:, :].values.reshape(-1, n, n_input_labels, 1)
# y_test = train_df[y_labels].iloc[split_index:, :].values

# y_test_indices = [range(i+y_offset, i+n) for i in range(0, len(train_df.iloc[split_index:, :])-n+1, n)]
# y_test = y_test[y_test_indices].reshape(-1, n-y_offset)

# %% [markdown]
# ### Batched sequences

# %%
# X_train, X_test, y_train, y_test = batch_sequence_split(train_df, 
#                                                         x_labels, 
#                                                         y_labels, 
#                                                         n, 
#                                                         n_input_labels,
#                                                         split_index)

# %% [markdown]
# ## Model

# %%
class Model():
    
    def __init__(self):
        self.mdl = None
        self.hist = None

    def create_model(self, input_shape, n_outputs):

        # Optimiser
        opt = Adam(lr=0.001)

        # define model
        self.mdl = Sequential()
        
        self.mdl.add(Conv2D(10, (10,1), input_shape=input_shape))
        self.mdl.add(MaxPooling2D(pool_size=(2,1)))
        self.mdl.add(Dropout(0.33))
        self.mdl.add(BatchNormalization())

        self.mdl.add(Conv2D(10, (5,1)))
        self.mdl.add(MaxPooling2D(pool_size=(2,1)))
        self.mdl.add(Dropout(0.33))
        self.mdl.add(BatchNormalization())

        self.mdl.add(Flatten())
        self.mdl.add(Dense(1500, activation='relu'))
        self.mdl.add(Dense(500, activation='relu'))

        self.mdl.add(Dense(n_outputs))

        # Prepare model for training
        self.mdl.compile(loss='mae',
                      optimizer=opt,
                      metrics=['mse'])

    
    def run_model(self, X_train, X_test, y_train, y_test):
    
        # Fit model
        self.hist = self.mdl.fit(X_train, y_train,
                            batch_size=1000,
                            epochs=100,
                            verbose=True,
                            validation_data=(X_test, y_test))

# %%
# Create Model
model = Model()
model.create_model(X_train[0].shape, n-y_offset)
# Out:
# WARNING:tensorflow:From /home/alastair/venvs/johnny5/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/alastair/venvs/johnny5/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.mdl.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 491, 3, 10)        110
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 245, 3, 10)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 245, 3, 10)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 245, 3, 10)        40
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 241, 3, 10)        510
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 120, 3, 10)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 120, 3, 10)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 120, 3, 10)        40
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1500)              5401500
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               750500
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               125250
# =================================================================
# Total params: 6,277,950
# Trainable params: 6,277,910
# Non-trainable params: 40
# _________________________________________________________________

# %%
model.run_model(X_train, X_test, y_train, y_test)
# Out:
# WARNING:tensorflow:From /home/alastair/venvs/johnny5/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 69650 samples, validate on 29850 samples
# Epoch 1/100
# 69650/69650 [==============================] - 5s 66us/step - loss: 0.1100 - mean_squared_error: 0.0425 - val_loss: 0.1182 - val_mean_squared_error: 0.0163
# Epoch 2/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.0407 - mean_squared_error: 0.0026 - val_loss: 0.0480 - val_mean_squared_error: 0.0034
# Epoch 3/100
# 69650/69650 [==============================] - 3s 47us/step - loss: 0.0373 - mean_squared_error: 0.0022 - val_loss: 0.2276 - val_mean_squared_error: 0.0538
# Epoch 4/100
# 69650/69650 [==============================] - 3s 46us/step - loss: 0.0348 - mean_squared_error: 0.0019 - val_loss: 0.1943 - val_mean_squared_error: 0.0406
# Epoch 5/100
# 69650/69650 [==============================] - 3s 47us/step - loss: 0.0319 - mean_squared_error: 0.0016 - val_loss: 0.1377 - val_mean_squared_error: 0.0228
# Epoch 6/100
# 69650/69650 [==============================] - 3s 47us/step - loss: 0.0290 - mean_squared_error: 0.0013 - val_loss: 0.0604 - val_mean_squared_error: 0.0059
# Epoch 7/100
# 69650/69650 [==============================] - 3s 46us/step - loss: 0.0261 - mean_squared_error: 0.0011 - val_loss: 0.0358 - val_mean_squared_error: 0.0021
# Epoch 8/100
# 69650/69650 [==============================] - 3s 46us/step - loss: 0.0246 - mean_squared_error: 9.6605e-04 - val_loss: 0.0263 - val_mean_squared_error: 0.0011
# Epoch 9/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.0233 - mean_squared_error: 8.6642e-04 - val_loss: 0.0431 - val_mean_squared_error: 0.0024
# Epoch 10/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0225 - mean_squared_error: 8.0732e-04 - val_loss: 0.0185 - val_mean_squared_error: 5.5025e-04
# Epoch 11/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0213 - mean_squared_error: 7.2720e-04 - val_loss: 0.0351 - val_mean_squared_error: 0.0017
# Epoch 12/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0209 - mean_squared_error: 6.9916e-04 - val_loss: 0.0347 - val_mean_squared_error: 0.0017
# Epoch 13/100
# 69650/69650 [==============================] - 3s 47us/step - loss: 0.0202 - mean_squared_error: 6.5379e-04 - val_loss: 0.0198 - val_mean_squared_error: 6.2269e-04
# Epoch 14/100
# 69650/69650 [==============================] - 3s 46us/step - loss: 0.0200 - mean_squared_error: 6.3729e-04 - val_loss: 0.0244 - val_mean_squared_error: 8.8165e-04
# Epoch 15/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.
100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0130 - mean_squared_error: 2.7369e-04 - val_loss: 0.0175 - val_mean_squared_error: 4.9506e-04
# Epoch 67/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0132 - mean_squared_error: 2.8023e-04 - val_loss: 0.0237 - val_mean_squared_error: 8.3964e-04
# Epoch 68/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0128 - mean_squared_error: 2.6446e-04 - val_loss: 0.0177 - val_mean_squared_error: 5.0001e-04
# Epoch 69/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0129 - mean_squared_error: 2.6898e-04 - val_loss: 0.0222 - val_mean_squared_error: 7.5089e-04
# Epoch 70/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0129 - mean_squared_error: 2.6994e-04 - val_loss: 0.0166 - val_mean_squared_error: 4.4838e-04
# Epoch 71/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0130 - mean_squared_error: 2.7165e-04 - val_loss: 0.0201 - val_mean_squared_error: 6.3138e-04
# Epoch 72/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0129 - mean_squared_error: 2.6870e-04 - val_loss: 0.0203 - val_mean_squared_error: 6.3478e-04
# Epoch 73/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0128 - mean_squared_error: 2.6426e-04 - val_loss: 0.0187 - val_mean_squared_error: 5.4817e-04
# Epoch 74/100
# 69650/69650 [==============================] - 3s 42us/step - loss: 0.0129 - mean_squared_error: 2.6762e-04 - val_loss: 0.0181 - val_mean_squared_error: 5.1901e-04
# Epoch 75/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0126 - mean_squared_error: 2.5705e-04 - val_loss: 0.0180 - val_mean_squared_error: 5.2577e-04
# Epoch 76/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0127 - mean_squared_error: 2.6084e-04 - val_loss: 0.0181 - val_mean_squared_error: 5.1996e-04
# Epoch 77/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0129 - mean_squared_error: 2.6808e-04 - val_loss: 0.0199 - val_mean_squared_error: 6.2352e-04
# Epoch 78/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0126 - mean_squared_error: 2.5648e-04 - val_loss: 0.0190 - val_mean_squared_error: 5.8454e-04
# Epoch 79/100
# 69650/69650 [==============================] - 3s 42us/step - loss: 0.0125 - mean_squared_error: 2.5206e-04 - val_loss: 0.0168 - val_mean_squared_error: 4.5897e-04
# Epoch 80/100
# 69650/69650 [==============================] - 3s 42us/step - loss: 0.0125 - mean_squared_error: 2.5301e-04 - val_loss: 0.0198 - val_mean_squared_error: 6.1889e-04
# Epoch 81/100
# 69650/69650 [==============================] - 3s 42us/step - loss: 0.0126 - mean_squared_error: 2.5780e-04 - val_loss: 0.0200 - val_mean_squared_error: 6.1827e-04
# Epoch 82/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0124 - mean_squared_error: 2.5039e-04 - val_loss: 0.0178 - val_mean_squared_error: 5.1001e-04
# Epoch 83/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0125 - mean_squared_error: 2.5274e-04 - val_loss: 0.0258 - val_mean_squared_error: 9.8549e-04
# Epoch 84/100
# 69650/69650 [==============================] - 3s 42us/step - loss: 0.0127 - mean_squared_error: 2.5996e-04 - val_loss: 0.0211 - val_mean_squared_error: 6.9819e-04
# Epoch 85/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0127 - mean_squared_error: 2.5804e-04 - val_loss: 0.0183 - val_mean_squared_error: 5.3709e-04
# Epoch 86/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0124 - mean_squared_error: 2.4950e-04 - val_loss: 0.0239 - val_mean_squared_error: 8.5642e-04
# Epoch 87/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0124 - mean_squared_error: 2.4825e-04 - val_loss: 0.0292 - val_mean_squared_error: 0.0012
# Epoch 88/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0124 - mean_squared_error: 2.4914e-04 - val_loss: 0.0164 - val_mean_squared_error: 4.3374e-04
# Epoch 89/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0125 - mean_squared_error: 2.5268e-04 - val_loss: 0.0212 - val_mean_squared_error: 6.9471e-04
# Epoch 90/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0123 - mean_squared_error: 2.4564e-04 - val_loss: 0.0187 - val_mean_squared_error: 5.5381e-04
# Epoch 91/100
# 69650/69650 [==============================] - 3s 42us/step - loss: 0.0122 - mean_squared_error: 2.4203e-04 - val_loss: 0.0190 - val_mean_squared_error: 5.6509e-04
# Epoch 92/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.0122 - mean_squared_error: 2.4002e-04 - val_loss: 0.0171 - val_mean_squared_error: 4.7242e-04
# Epoch 93/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0122 - mean_squared_error: 2.4113e-04 - val_loss: 0.0181 - val_mean_squared_error: 5.2971e-04
# Epoch 94/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.0121 - mean_squared_error: 2.3737e-04 - val_loss: 0.0206 - val_mean_squared_error: 6.8590e-04
# Epoch 95/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0122 - mean_squared_error: 2.3990e-04 - val_loss: 0.0171 - val_mean_squared_error: 4.7605e-04
# Epoch 96/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.0121 - mean_squared_error: 2.3694e-04 - val_loss: 0.0173 - val_mean_squared_error: 4.8322e-04
# Epoch 97/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0121 - mean_squared_error: 2.3808e-04 - val_loss: 0.0176 - val_mean_squared_error: 4.9766e-04
# Epoch 98/100
# 69650/69650 [==============================] - 3s 44us/step - loss: 0.0121 - mean_squared_error: 2.3601e-04 - val_loss: 0.0187 - val_mean_squared_error: 5.5079e-04
# Epoch 99/100
# 69650/69650 [==============================] - 3s 43us/step - loss: 0.0121 - mean_squared_error: 2.3726e-04 - val_loss: 0.0261 - val_mean_squared_error: 9.8209e-04
# Epoch 100/100
# 69650/69650 [==============================] - 3s 45us/step - loss: 0.0120 - mean_squared_error: 2.3327e-04 - val_loss: 0.0178 - val_mean_squared_error: 5.0144e-04

# %% [markdown]
# ## Evaluation

# %%
# Scores
print(model.mdl.evaluate(X_test, y_test, verbose=0))
# Out:
# [0.01775722967245471, 0.0005014374106186418]

# %%
# Error plot (%)
preds = model.mdl.predict(X_test)
resids_all = preds-y_test
resids = pd.DataFrame((preds - y_test).reshape(-1))
resids.plot(kind='hist', bins=100, title='Residuals Histogram')
print(resids.describe())
# Out:
#                   0
# count  7.462500e+06
# mean  -6.072662e-03
# std    2.155366e-02
# min   -1.152166e-01
# 25%   -2.028010e-02
# 50%   -6.628664e-03
# 75%    7.463014e-03
# max    1.318061e-01

# %%
comparison = pd.concat([pd.DataFrame(preds[0].reshape(-1), columns=['preds']), 
                        pd.DataFrame(y_test[0].reshape(-1), columns=['true'])], axis=1)

# %%
comparison.plot(figsize=(15,10))

# %%
pd.DataFrame((resids_all[0])).plot(figsize=(15,10))

# %%
comparison.std()
# Out:
# preds    0.048514
# true     0.049969
# dtype: float64

# %%
comparison.mean()
# Out:
# preds    0.465528
# true     0.451490
# dtype: float64

# %%
r2_score(y_test, preds)
# Out:
# 0.7038877707139141

# %% [markdown]
# ## Scaled

# %%
disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')

# %%
disp_df = pd.DataFrame(disp_raw.T, columns=['disp', 'disp_10noise'])['disp_10noise']

# %%
mean = disp_df.mean()
minimum = disp_df.min()
maximum = disp_df.max()

# %%
scaled_resids = pd.DataFrame(((((resids_all -0.5) * 2.0) * (maximum - minimum)) + mean).reshape(-1))

# %%
scaled_resids.mean()
# Out:
# 0   -0.006349
# dtype: float64

# %%
scaled_resids.plot(kind='hist', bins=100, figsize=(15,10), title='Errors Histogram for SDOF Problem with 10% Noise')
print('Error Standard Deviation: %E' % scaled_resids.std())
print('Error Mean: %E' % scaled_resids.mean())
# Out:
# Error Standard Deviation: 2.703863E-04
# Error Mean: -6.349442E-03
