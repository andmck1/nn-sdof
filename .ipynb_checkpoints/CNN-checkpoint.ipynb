# %% [markdown]
# ## Imports

# %%
# File
import pathlib
import pickle

# %%
# Data
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import skew, skewtest

# %%
# Charting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Deep Learning
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, MaxPool1D, Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from keras.optimizers import Adam, RMSprop
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get Data

# %%
X_train = pickle.load(open('./data/X_train.pkl', 'rb'))
X_test = pickle.load(open('./data/X_test.pkl', 'rb'))
y_train = pickle.load(open('./data/y_train.pkl', 'rb'))
y_test = pickle.load(open('./data/y_test.pkl', 'rb'))

# %% [markdown]
# ## Model

# %%
tb_callback = TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

# %%
class Model():

    def __init__(self):
        self.mdl = None
        self.hist = None

    def create_model(self, input_shape, n_outputs):

        # Optimiser
        opt = Adam(lr=0.001)

        # define model
        self.mdl = Sequential()

        self.mdl.add(Conv2D(9, (2,1), input_shape=input_shape))
        self.mdl.add(Dropout(0.2))
        self.mdl.add(BatchNormalization())

        self.mdl.add(Flatten())
        self.mdl.add(Dense(500, activation='relu'))
        self.mdl.add(Dropout(0.2))
        self.mdl.add(BatchNormalization())
        
        self.mdl.add(Dense(n_outputs))

        # Prepare model for training
        self.mdl.compile(loss='mae',
                      optimizer=opt,
                      metrics=['mse'])


    def run_model(self, X_train, X_test, y_train, y_test, callback):

        # Fit model
        self.hist = self.mdl.fit(X_train, y_train,
                                batch_size=1000,
                                epochs=100,
                                verbose=True,
                                validation_data=(X_test, y_test),
                                callbacks=[callback])

# %%
# Create Model
model = Model()
model.create_model(X_train[0].shape, n-y_offset)

# %%
model.mdl.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 99, 2, 9)          27
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 99, 2, 9)          0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 99, 2, 9)          36
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 1782)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 500)               891500
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 500)               0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 500)               2000
# _________________________________________________________________
# dense_6 (Dense)              (None, 99)                49599
# =================================================================
# Total params: 943,162
# Trainable params: 942,144
# Non-trainable params: 1,018
# _________________________________________________________________

# %%
model.run_model(X_train, X_test, y_train, y_test, tb_callback)
# Out:
# Train on 69860 samples, validate on 29940 samples
# Epoch 1/100
# 69860/69860 [==============================] - 1s 13us/step - loss: 0.6096 - mean_squared_error: 0.6614 - val_loss: 0.2051 - val_mean_squared_error: 0.0661
# Epoch 2/100
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.1523 - mean_squared_error: 0.0430 - val_loss: 0.0712 - val_mean_squared_error: 0.0077
# Epoch 3/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0693 - mean_squared_error: 0.0077 - val_loss: 0.0423 - val_mean_squared_error: 0.0028
# Epoch 4/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0558 - mean_squared_error: 0.0049 - val_loss: 0.0374 - val_mean_squared_error: 0.0022
# Epoch 5/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0491 - mean_squared_error: 0.0038 - val_loss: 0.0344 - val_mean_squared_error: 0.0019
# Epoch 6/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0450 - mean_squared_error: 0.0032 - val_loss: 0.0328 - val_mean_squared_error: 0.0017
# Epoch 7/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0419 - mean_squared_error: 0.0028 - val_loss: 0.0309 - val_mean_squared_error: 0.0015
# Epoch 8/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0396 - mean_squared_error: 0.0025 - val_loss: 0.0301 - val_mean_squared_error: 0.0014
# Epoch 9/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0378 - mean_squared_error: 0.0023 - val_loss: 0.0292 - val_mean_squared_error: 0.0013
# Epoch 10/100
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0366 - mean_squared_error: 0.0021 - val_loss: 0.0288 - val_mean_squared_error: 0.0013
# Epoch 11/100
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0355 - mean_squared_error: 0.0020 - val_loss: 0.0284 - val_mean_squared_error: 0.0013
# Epoch 12/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0346 - mean_squared_error: 0.0019 - val_loss: 0.0279 - val_mean_squared_error: 0.0012
# Epoch 13/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0339 - mean_squared_error: 0.0018 - val_loss: 0.0277 - val_mean_squared_error: 0.0012
# Epoch 14/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0333 - mean_squared_error: 0.0017 - val_loss: 0.0272 - val_mean_squared_error: 0.0012
# Epoch 15/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0328 - mean_squared_error: 0.0017 - val_loss: 0.0272 - val_mean_squared_error: 0.0012
# Epoch 16/100
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0324 - mean_squared_error: 0.0017 - val_loss: 0.0271 - val_mean_squared_error: 0.0012
# Epoch 17/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0321 - mean_squared_error: 0.0016 - val_loss: 0.0270 - val_mean_squared_error: 0.0011
# Epoch 18/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0318 - mean_squared_error: 0.0016 - val_loss: 0.0269 - val_mean_squared_error: 0.0011
# Epoch 19/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0316 - mean_squared_error: 0.0016 - val_loss: 0.0267 - val_mean_squared_error: 0.0011
# Epoch 20/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0314 - mean_squared_error: 0.0016 - val_loss: 0.0266 - val_mean_squared_error: 0.0011
# Epoch 21/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0311 - mean_squared_error: 0.0015 - val_loss: 0.0265 - val_mean_squared_error: 0.0011
# Epoch 22/100
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0309 - mean_squared_error: 0.0015 - val_loss: 0.0267 - val_mean_squared_error: 0.0011
# Epoch 23/100
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0309 - mean_squared_error: 0.0015 - val_loss: 0.0264 - val_mean_squared_error: 0.0011
# Epoch 24/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0307 - mean_squared_error: 0.0015 - val_loss: 0.0263 - val_mean_squared_error: 0.0011
# Epoch 25/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0306 - mean_squared_error: 0.0015 - val_loss: 0.0264 - val_mean_squared_error: 0.0011
# Epoch 26/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0304 - mean_squared_error: 0.0015 - val_loss: 0.0263 - val_mean_squared_error: 0.0011
# Epoch 27/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0302 - mean_squared_error: 0.0014 - val_loss: 0.0261 - val_mean_squared_error: 0.0011
# Epoch 28/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0302 - mean_squared_error: 0.0014 - val_loss: 0.0262 - val_mean_squared_error: 0.0011
# Epoch 29/100
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0302 - mean_squared_error: 0.0014 - val_loss: 0.0261 - val_mean_squared_error: 0.0011
# Epoch 30/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0300 - mean_squared_error: 0.0014 - val_loss: 0.0261 - val_mean_squared_error: 0.0011
# Epoch 31/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0299 - mean_squared_error: 0.0014 - val_loss: 0.0260 - val_mean_squared_error: 0.0011
# Epoch 32/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0298 - mean_squared_error: 0.0014 - val_loss: 0.0259 - val_mean_squared_error: 0.0011
# Epoch 33/100
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.
# %%
# Scores
print(model.mdl.evaluate(X_test, y_test, verbose=0))
# Out:
# [0.024036720915185505, 0.0009084432479025237]

# %%
# Error plot (%)
preds = model.mdl.predict(X_test)
resids_all = preds-y_test
resids = pd.DataFrame((preds - y_test).reshape(-1))
resids.plot(kind='hist', bins=100, title='Residuals Histogram')
print(resids.describe())
# Out:
#                   0
# count  2.964060e+06
# mean  -9.932855e-06
# std    3.014040e-02
# min   -1.465945e-01
# 25%   -2.037389e-02
# 50%   -1.169635e-04
# 75%    2.026567e-02
# max    1.533409e-01

# %%
print(skew(resids)[0])
print(skewtest(resids))
# Out:
# 0.019708421391263792
# SkewtestResult(statistic=array([13.85092078]), pvalue=array([1.25591758e-43]))

# %%
comp_ind = 1000
comparison = pd.concat([pd.DataFrame(preds[comp_ind].reshape(-1), columns=['preds']), 
                        pd.DataFrame(y_test[comp_ind].reshape(-1), columns=['true'])], axis=1)
comparison.plot(figsize=(15,10))

# %%
indices = np.random.randint(low=0, high=len(resids_all), size=1)
pd.DataFrame((resids_all[indices])).T.plot(figsize=(15,10), legend=False)

# %%
r2_score(y_test, preds)
# Out:
# 0.7527096087099883

# %% [markdown]
# ## Scaled

# %%
disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-9d2f845a91d7> in <module>
# ----> 1 disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1937             converters = [StringConverter(dtype, locked=True,
#    1938                                           missing_values=miss, default=fill)
# -> 1939                           for (miss, fill) in zipit]
#    1940     # Update the converters to use the user-defined ones
#    1941     uc_update = []
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1937             converters = [StringConverter(dtype, locked=True,
#    1938                                           missing_values=miss, default=fill)
# -> 1939                           for (miss, fill) in zipit]
#    1940     # Update the converters to use the user-defined ones
#    1941     uc_update = []
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/_iotools.py in __init__(self, dtype_or_func, default, missing_values, locked)
#     698             if isinstance(missing_values, basestring):
#     699                 missing_values = missing_values.split(",")
# --> 700             self.missing_values = set(list(missing_values) + [''])
#     701         #
#     702         self._callingfunction = self._strict_call
#
# KeyboardInterrupt:

# %%
disp_df = pd.DataFrame(disp_raw.T, columns=['disp', 'disp_10noise'])['disp_10noise']

# %%
mean = disp_df.mean()
minimum = disp_df.min()
maximum = disp_df.max()

# %%
scaled_resids = pd.DataFrame(((((resids_all -0.5) * 2.0) * (maximum - minimum)) + mean).reshape(-1))

# %%
scaled_resids.mean()

# %%
scaled_resids.plot(kind='hist', bins=100, figsize=(15,10), title='Errors Histogram for SDOF Problem with 10% Noise')
print('Error Standard Deviation: %E' % scaled_resids.std())
print('Error Mean: %E' % scaled_resids.mean())
