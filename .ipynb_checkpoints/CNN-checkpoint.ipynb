# %% [markdown]
# ## Imports

# %%
# File
import pathlib
import pickle

# %%
# Data
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import skew, skewtest

# %%
# Charting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Deep Learning
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPool1D, Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Get Data

# %%
X_train = pickle.load(open('./data/X_train.pkl', 'rb'))
X_test = pickle.load(open('./data/X_test.pkl', 'rb'))
y_train = pickle.load(open('./data/y_train.pkl', 'rb'))
y_test = pickle.load(open('./data/y_test.pkl', 'rb'))

# %%
del X_train, X_test, y_train, y_test

# %%
X_valid = pickle.load(open('./data/X_valid.pkl', 'rb'))
y_valid = pickle.load(open('./data/y_valid.pkl', 'rb'))

# %% [markdown]
# ## Model

# %%
tb_callback = TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

# %%
class Model():

    def __init__(self):
        self.mdl = None
        self.hist = None

    def create_model(self, input_shape, n_outputs):

        # Optimiser
        opt = Adam(lr=0.001)

        # define model
        self.mdl = Sequential()

        self.mdl.add(Conv2D(9, (2,1), input_shape=input_shape))
        self.mdl.add(Dropout(0.2))
        self.mdl.add(BatchNormalization())

        self.mdl.add(Flatten())
        self.mdl.add(Dense(500, activation='relu'))
        self.mdl.add(Dropout(0.2))
        self.mdl.add(BatchNormalization())
        
        self.mdl.add(Dense(n_outputs))

        # Prepare model for training
        self.mdl.compile(loss='mae',
                      optimizer=opt,
                      metrics=['mse'])


    def run_model(self, X_train, X_test, y_train, y_test, callback):

        # Fit model
        self.hist = self.mdl.fit(X_train, y_train,
                                batch_size=1000,
                                epochs=100,
                                verbose=True,
                                validation_data=(X_test, y_test),
                                callbacks=[callback])

# %%
# Create Model
model = Model()
model.create_model(X_train[0].shape, y_train.shape[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e73b10fc7af0> in <module>
#       1 # Create Model
#       2 model = Model()
# ----> 3 model.create_model(X_train[0].shape, y_train.shape[1])
#
# NameError: name 'X_train' is not defined

# %%
model.mdl.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 99, 2, 9)          27
# _________________________________________________________________
# dropout (Dropout)            (None, 99, 2, 9)          0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 99, 2, 9)          36
# _________________________________________________________________
# flatten (Flatten)            (None, 1782)              0
# _________________________________________________________________
# dense (Dense)                (None, 500)               891500
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 500)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 500)               2000
# _________________________________________________________________
# dense_1 (Dense)              (None, 99)                49599
# =================================================================
# Total params: 943,162
# Trainable params: 942,144
# Non-trainable params: 1,018
# _________________________________________________________________

# %%
model.run_model(X_train, X_test, y_train, y_test, tb_callback)
# Out:
# Epoch 1/100
# 70/70 [==============================] - 6s 75ms/step - loss: 0.5152 - mse: 0.4737 - val_loss: 0.1528 - val_mse: 0.0365
# Epoch 2/100
# 70/70 [==============================] - 5s 68ms/step - loss: 0.1435 - mse: 0.0367 - val_loss: 0.1427 - val_mse: 0.0319
# Epoch 3/100
# 70/70 [==============================] - 5s 68ms/step - loss: 0.0881 - mse: 0.0124 - val_loss: 0.1256 - val_mse: 0.0247
# Epoch 4/100
# 70/70 [==============================] - 5s 71ms/step - loss: 0.0817 - mse: 0.0107 - val_loss: 0.1041 - val_mse: 0.0170
# Epoch 5/100
# 70/70 [==============================] - 5s 74ms/step - loss: 0.0786 - mse: 0.0099 - val_loss: 0.0840 - val_mse: 0.0111
# Epoch 6/100
# 70/70 [==============================] - 5s 70ms/step - loss: 0.0769 - mse: 0.0095 - val_loss: 0.0667 - val_mse: 0.0070
# Epoch 7/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0758 - mse: 0.0092 - val_loss: 0.0541 - val_mse: 0.0046
# Epoch 8/100
# 70/70 [==============================] - 5s 75ms/step - loss: 0.0750 - mse: 0.0090 - val_loss: 0.0459 - val_mse: 0.0034
# Epoch 9/100
# 70/70 [==============================] - 5s 79ms/step - loss: 0.0746 - mse: 0.0089 - val_loss: 0.0416 - val_mse: 0.0028
# Epoch 10/100
# 70/70 [==============================] - 5s 76ms/step - loss: 0.
100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0570 - mse: 0.0082 - val_loss: 0.0307 - val_mse: 0.0017
# Epoch 79/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0569 - mse: 0.0082 - val_loss: 0.0306 - val_mse: 0.0017
# Epoch 80/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0567 - mse: 0.0082 - val_loss: 0.0309 - val_mse: 0.0017
# Epoch 81/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0566 - mse: 0.0082 - val_loss: 0.0308 - val_mse: 0.0017
# Epoch 82/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0566 - mse: 0.0082 - val_loss: 0.0311 - val_mse: 0.0017
# Epoch 83/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0565 - mse: 0.0083 - val_loss: 0.0312 - val_mse: 0.0018
# Epoch 84/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0564 - mse: 0.0083 - val_loss: 0.0313 - val_mse: 0.0018
# Epoch 85/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0564 - mse: 0.0083 - val_loss: 0.0311 - val_mse: 0.0017
# Epoch 86/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0562 - mse: 0.0083 - val_loss: 0.0312 - val_mse: 0.0018
# Epoch 87/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0562 - mse: 0.0083 - val_loss: 0.0311 - val_mse: 0.0018
# Epoch 88/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0562 - mse: 0.0083 - val_loss: 0.0311 - val_mse: 0.0018
# Epoch 89/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0561 - mse: 0.0083 - val_loss: 0.0312 - val_mse: 0.0018
# Epoch 90/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0560 - mse: 0.0083 - val_loss: 0.0314 - val_mse: 0.0018
# Epoch 91/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0559 - mse: 0.0083 - val_loss: 0.0313 - val_mse: 0.0018
# Epoch 92/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0559 - mse: 0.0083 - val_loss: 0.0316 - val_mse: 0.0018
# Epoch 93/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0558 - mse: 0.0083 - val_loss: 0.0313 - val_mse: 0.0018
# Epoch 94/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0557 - mse: 0.0083 - val_loss: 0.0316 - val_mse: 0.0018
# Epoch 95/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0557 - mse: 0.0083 - val_loss: 0.0317 - val_mse: 0.0018
# Epoch 96/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0557 - mse: 0.0083 - val_loss: 0.0314 - val_mse: 0.0018
# Epoch 97/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0557 - mse: 0.0083 - val_loss: 0.0314 - val_mse: 0.0018
# Epoch 98/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0556 - mse: 0.0083 - val_loss: 0.0315 - val_mse: 0.0018
# Epoch 99/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0555 - mse: 0.0083 - val_loss: 0.0316 - val_mse: 0.0018
# Epoch 100/100
# 70/70 [==============================] - 5s 72ms/step - loss: 0.0555 - mse: 0.0083 - val_loss: 0.0316 - val_mse: 0.0018

# %%
model.mdl.save('./data/cnn-model')
# Out:
# INFO:tensorflow:Assets written to: ./data/cnn-model/assets

# %%
model = Model()

# %%
model.mdl = load_model('./data/cnn-model')

# %% [markdown]
# ## Evaluation

# %%
# Scores
print(model.mdl.evaluate(X_test, y_test, verbose=0, batch_size=16))
# Out:
# [0.25367048382759094, 0.10326166450977325]

# %%
# Error plot (%)
preds = model.mdl.predict(X_test)
resids_all = preds-y_test
resids = pd.DataFrame((preds - y_test).reshape(-1))
resids.plot(kind='hist', bins=100, title='Residuals Histogram')
print(resids.describe())
# Out:
#                   0
# count  99000.000000
# mean      -0.105079
# std        0.303679
# min       -1.398169
# 25%       -0.313261
# 50%       -0.089355
# 75%        0.094239
# max        0.856049

# %%
print(skew(resids)[0])
print(skewtest(resids))
# Out:
# -0.08108935817695238
# SkewtestResult(statistic=array([-10.39986098]), pvalue=array([2.48295179e-25]))

# %%
comp_ind = 1000
comparison = pd.concat([pd.DataFrame(preds[comp_ind].reshape(-1), columns=['preds']), 
                        pd.DataFrame(y_test[comp_ind].reshape(-1), columns=['true'])], axis=1)
comparison.plot(figsize=(15,10))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-aa2f27fe6079> in <module>
#       1 comp_ind = 1000
# ----> 2 comparison = pd.concat([pd.DataFrame(preds[comp_ind].reshape(-1), columns=['preds']),
#       3                         pd.DataFrame(y_test[comp_ind].reshape(-1), columns=['true'])], axis=1)
#       4 comparison.plot(figsize=(15,10))
#
# IndexError: index 1000 is out of bounds for axis 0 with size 1000

# %%
indices = np.random.randint(low=0, high=len(resids_all), size=1)
pd.DataFrame((resids_all[indices])).T.plot(figsize=(15,10), legend=False)
# Out:
# <AxesSubplot:>

# %%
r2_score(y_test, preds)
# Out:
# 0.9668898829465232

# %% [markdown]
# ## Validation

# %%
# Scores
print(model.mdl.evaluate(X_valid[:1000], y_valid[:1000], verbose=0, batch_size=1))
# Out:
# [0.25367048382759094, 0.10326166450977325]

# %%
# Error plot (%)
preds = model.mdl.predict(X_valid[:10000], batch_size=1)
resids_all = preds-y_valid[:10000]
resids = pd.DataFrame((preds - y_valid[:10000]).reshape(-1))
resids.plot(kind='hist', bins=100, title='Residuals Histogram')
print(resids.describe())
# Out:
#                    0
# count  990000.000000
# mean       -0.105025
# std         0.299746
# min        -1.468427
# 25%        -0.305573
# 50%        -0.103405
# 75%         0.097153
# max         1.063940

# %%
print(skew(resids)[0])
print(skewtest(resids))
# Out:
# -0.01913555370086985
# SkewtestResult(statistic=array([-7.77224618]), pvalue=array([7.71064055e-15]))

# %%
comp_ind = 100
comparison = pd.concat([pd.DataFrame(preds[comp_ind].reshape(-1), columns=['preds']), 
                        pd.DataFrame(y_valid[comp_ind].reshape(-1), columns=['true'])], axis=1)
comparison.plot(figsize=(15,10))
# Out:
# <AxesSubplot:>

# %%
indices = np.random.randint(low=0, high=len(resids_all), size=1)
pd.DataFrame((resids_all[indices])).T.plot(figsize=(15,10), legend=False)
# Out:
# <AxesSubplot:>

# %%
r2_score(y_valid[:10000], preds)
# Out:
# -1.0108856177287289

# %% [markdown]
# ## Scaled

# %%
disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-9d2f845a91d7> in <module>
# ----> 1 disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1937             converters = [StringConverter(dtype, locked=True,
#    1938                                           missing_values=miss, default=fill)
# -> 1939                           for (miss, fill) in zipit]
#    1940     # Update the converters to use the user-defined ones
#    1941     uc_update = []
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1937             converters = [StringConverter(dtype, locked=True,
#    1938                                           missing_values=miss, default=fill)
# -> 1939                           for (miss, fill) in zipit]
#    1940     # Update the converters to use the user-defined ones
#    1941     uc_update = []
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/_iotools.py in __init__(self, dtype_or_func, default, missing_values, locked)
#     698             if isinstance(missing_values, basestring):
#     699                 missing_values = missing_values.split(",")
# --> 700             self.missing_values = set(list(missing_values) + [''])
#     701         #
#     702         self._callingfunction = self._strict_call
#
# KeyboardInterrupt:

# %%
disp_df = pd.DataFrame(disp_raw.T, columns=['disp', 'disp_10noise'])['disp_10noise']

# %%
mean = disp_df.mean()
minimum = disp_df.min()
maximum = disp_df.max()

# %%
scaled_resids = pd.DataFrame(((((resids_all -0.5) * 2.0) * (maximum - minimum)) + mean).reshape(-1))

# %%
scaled_resids.mean()

# %%
scaled_resids.plot(kind='hist', bins=100, figsize=(15,10), title='Errors Histogram for SDOF Problem with 10% Noise')
print('Error Standard Deviation: %E' % scaled_resids.std())
print('Error Mean: %E' % scaled_resids.mean())
