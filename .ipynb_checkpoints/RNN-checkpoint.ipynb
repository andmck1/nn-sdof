# %% [markdown]
# ## Imports

# %%
# File
import pathlib

# %%
# Data
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from scipy.stats import skew, skewtest

# %%
# Charting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Deep Learning
from keras.models import Sequential
from keras.layers import Conv1D, Dropout, MaxPool1D, Dense, Flatten, BatchNormalization, Conv2D, MaxPooling2D
from keras.layers import SimpleRNN, LSTM, TimeDistributed, Reshape
from keras.optimizers import Adam, RMSprop
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Preprocessing functions

# %%
def walk_forward(df, x_labels, y_labels, n, n_input_labels, 
                 split_per=None, split_data=False, y_offset=0):
    
    td_shape = df.shape
    td_l = td_shape[0]
    
    x_indices = [range(i, i+n) for i in range(td_l-n)]
    y_indices = [range(i+y_offset, i+n) for i in range(td_l-n)]
    
    x = df.loc[:, x_labels].values[x_indices]
    y = df.loc[:, y_labels].values[y_indices]
    
    if split_data:
        split_index = int(len(x)*split_per)
        x = x.reshape(-1, n, n_input_labels, 1)
        y = y.reshape(-1, n-y_offset)
        X_train, X_test, y_train, y_test = (x[:split_index], x[split_index:], y[:split_index], y[split_index:])
        return X_train, X_test, y_train, y_test
    
    return x, y

# %%
def batch_sequence_split(df, x_labels, y_labels, n, n_input_labels, split_index):
    
    X_train = df[x_labels].iloc[:split_index].values.reshape(-1, n, n_input_labels, 1)
    X_test = df[x_labels].iloc[split_index:].values.reshape(-1, n, n_input_labels, 1)
    y_train = df[y_labels].iloc[:split_index].values.reshape(-1, n)
    y_test = df[y_labels].iloc[split_index:].values.reshape(-1, n)
    
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Get Data

# %%
train_df = pd.read_pickle('./data/train_df.pkl')

# %%
train_10noise_df = (pd.read_pickle('./data/10per_noise_train_df.pkl'))

# %% [markdown]
# ## Generate Data

# %%
from get_data import newmann_beta

# %%
time_steps = 1660000

# %%
m = 1.0
k = 200
c = 1.5
dt = 1/200
f = 2.0 * (np.random.rand(time_steps) - 0.5)

# %%
gen_data = newmann_beta(m, c, k, dt, f, time_steps)

# %%
# gen_data['acc'] = gen_data['acc'] + np.random.normal(scale=0.5*gen_data['acc'].std(), size=len(f))

# %%
gen_data = gen_data.rename({'dis': 'disp'}, axis=1)

# %%
for col in gen_data.columns:
    mean = gen_data[col].mean()
    minimum = gen_data[col].min()
    maximum = gen_data[col].max()
    gen_data[col] = (gen_data[col]-mean)/(maximum - minimum)
    gen_data[col] = gen_data[col] / 2.0 + 0.5

# %% [markdown]
# ## Preprocessing

# %%
n = 100

# %%
# train_df = train_10noise_df.iloc[:100000, :].join(train_df['disp'])
train_df = gen_data.iloc[:100000, :]
delayed_acc = train_df['acc'][:len(train_df)-n].rename('del_acc')
train_df = train_df.iloc[n:, :].reset_index(drop=True).join(delayed_acc)
train_df.head()
# Out:
#         exc      disp       vel       acc   del_acc
# 0  0.379676  0.545651  0.550290  0.418001  0.421301
# 1  0.494496  0.549013  0.543558  0.465524  0.469532
# 2  0.483472  0.552012  0.539213  0.459299  0.503492
# 3  0.721214  0.554819  0.540282  0.559209  0.427698
# 4  0.481107  0.557836  0.541085  0.454686  0.542418

# %%
train_df.loc[:200, :].plot()

# %% [markdown]
# ### Some config params

# %%
td_shape = train_df.shape
td_l = td_shape[0]

# %%
x_labels = ['exc', 'del_acc']
y_labels = ['acc']

# %%
n_input_labels = len(x_labels)
y_offset = 1

# %%
train_percentage = 0.7
length_train_data = len(train_df)
split_index = int(length_train_data*train_percentage)

# %%
split_index
# Out:
# 69930

# %% [markdown]
# ## Get train and test data

# %% [markdown]
# ### Walk forward

# %%
# X_train, X_test, y_train, y_test = walk_forward(train_df, 
#                                                 x_labels, y_labels, 
#                                                 n, n_input_labels, y_offset=y_offset,
#                                                 split_per=0.7, split_data=True)

# X_train = X_train.reshape(-1, n, n_input_labels, 1)
# y_train = y_train.reshape(-1, n-y_offset)

# X_test = train_df[x_labels].iloc[split_index:, :].values.reshape(-1, n, n_input_labels, 1)
# y_test = train_df[y_labels].iloc[split_index:, :].values

# y_test_indices = [range(i+y_offset, i+n) for i in range(0, len(train_df.iloc[split_index:, :])-n+1, n)]
# y_test = y_test[y_test_indices].reshape(-1, n-y_offset)

# %% [markdown]
# ### Batched sequences

# %%
# X_train, X_test, y_train, y_test = batch_sequence_split(train_df, 
#                                                         x_labels, 
#                                                         y_labels, 
#                                                         n, 
#                                                         n_input_labels,
#                                                         split_index)

# %% [markdown]
# ### Generator

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, labels, batch_size=32, dim=(32,32,32), n_channels=1,
                 n_classes=10, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_classes = n_classes
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, list_IDs_temp):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((self.batch_size, *self.dim, self.n_channels))
        y = np.empty((self.batch_size), dtype=int)

        # Generate data
        for i, ID in enumerate(list_IDs_temp):
            # Store sample
            X[i,] = np.load('data/' + ID + '.npy')

            # Store class
            y[i] = self.labels[ID]

        return X, keras.utils.to_categorical(y, num_classes=self.n_classes)

# %% [markdown]
# ## Model

# %%
tb_callback = TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

# %%
class Model():

    def __init__(self):
        self.mdl = None
        self.hist = None

    def create_model(self, input_shape, n_outputs):

        # Optimiser
        opt = Adam(lr=0.001)

        # define model
        self.mdl = Sequential()
        
        self.mdl.add(Conv2D(9, (2,1), input_shape=input_shape))
        self.mdl.add(Dropout(0.2))
        self.mdl.add(BatchNormalization())
        
        self.mdl.add(Flatten())
        self.mdl.add(Dense(200, activation='relu'))
        self.mdl.add(Dropout(0.2))
        self.mdl.add(BatchNormalization())
        
        self.mdl.add(Dense(n_outputs))
        
        # Prepare model for training
        self.mdl.compile(loss='mae',
                      optimizer=opt,
                      metrics=['mse'])


    def run_model(self, X_train, X_test, y_train, y_test, callback):

        # Fit model
        self.hist = self.mdl.fit(X_train, y_train,
                                batch_size=1000,
                                epochs=20,
                                verbose=True,
                                validation_data=(X_test, y_test),
                                callbacks=[callback])

# %%
# Create Model
model = Model()
model.create_model(X_train[0].shape, n-y_offset)

# %%
model.mdl.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 99, 2, 9)          27
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 99, 2, 9)          0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 99, 2, 9)          36
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 1782)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               356600
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 200)               0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 200)               800
# _________________________________________________________________
# dense_10 (Dense)             (None, 99)                19899
# =================================================================
# Total params: 377,362
# Trainable params: 376,944
# Non-trainable params: 418
# _________________________________________________________________

# %%
model.run_model(X_train, X_test, y_train, y_test, tb_callback)
# Out:
# Train on 69860 samples, validate on 29940 samples
# Epoch 1/20
# 69860/69860 [==============================] - 1s 13us/step - loss: 0.6239 - mean_squared_error: 0.6566 - val_loss: 0.2376 - val_mean_squared_error: 0.0879
# Epoch 2/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.2085 - mean_squared_error: 0.0778 - val_loss: 0.0876 - val_mean_squared_error: 0.0117
# Epoch 3/20
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0866 - mean_squared_error: 0.0124 - val_loss: 0.0607 - val_mean_squared_error: 0.0057
# Epoch 4/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0675 - mean_squared_error: 0.0074 - val_loss: 0.0540 - val_mean_squared_error: 0.0045
# Epoch 5/20
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0590 - mean_squared_error: 0.0056 - val_loss: 0.0402 - val_mean_squared_error: 0.0025
# Epoch 6/20
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0529 - mean_squared_error: 0.0044 - val_loss: 0.0349 - val_mean_squared_error: 0.0019
# Epoch 7/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0483 - mean_squared_error: 0.0037 - val_loss: 0.0311 - val_mean_squared_error: 0.0015
# Epoch 8/20
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0444 - mean_squared_error: 0.0031 - val_loss: 0.0283 - val_mean_squared_error: 0.0013
# Epoch 9/20
# 69860/69860 [==============================] - 1s 10us/step - loss: 0.0413 - mean_squared_error: 0.0027 - val_loss: 0.0258 - val_mean_squared_error: 0.0010
# Epoch 10/20
# 69860/69860 [==============================] - 1s 7us/step - loss: 0.0387 - mean_squared_error: 0.0024 - val_loss: 0.0233 - val_mean_squared_error: 8.4923e-04
# Epoch 11/20
# 69860/69860 [==============================] - 1s 7us/step - loss: 0.0367 - mean_squared_error: 0.0021 - val_loss: 0.0227 - val_mean_squared_error: 8.0560e-04
# Epoch 12/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0352 - mean_squared_error: 0.0020 - val_loss: 0.0221 - val_mean_squared_error: 7.5905e-04
# Epoch 13/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0340 - mean_squared_error: 0.0018 - val_loss: 0.0212 - val_mean_squared_error: 6.9869e-04
# Epoch 14/20
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0331 - mean_squared_error: 0.0017 - val_loss: 0.0210 - val_mean_squared_error: 6.8208e-04
# Epoch 15/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0324 - mean_squared_error: 0.0017 - val_loss: 0.0209 - val_mean_squared_error: 6.7965e-04
# Epoch 16/20
# 69860/69860 [==============================] - 1s 9us/step - loss: 0.0318 - mean_squared_error: 0.0016 - val_loss: 0.0203 - val_mean_squared_error: 6.3704e-04
# Epoch 17/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0313 - mean_squared_error: 0.0015 - val_loss: 0.0200 - val_mean_squared_error: 6.1472e-04
# Epoch 18/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0309 - mean_squared_error: 0.0015 - val_loss: 0.0198 - val_mean_squared_error: 6.0714e-04
# Epoch 19/20
# 69860/69860 [==============================] - 1s 8us/step - loss: 0.0306 - mean_squared_error: 0.0015 - val_loss: 0.0201 - val_mean_squared_error: 6.2224e-04
# Epoch 20/20
# 69860/69860 [==============================] - 1s 7us/step - loss: 0.0304 - mean_squared_error: 0.0015 - val_loss: 0.0197 - val_mean_squared_error: 5.9980e-04

# %% [markdown]
# ## Evaluation

# %%
# Scores
print(model.mdl.evaluate(X_test, y_test, verbose=0))
# Out:
# [0.01972991562508788, 0.0005997967030109592]

# %%
# Error plot (%)
preds = model.mdl.predict(X_test)
resids_all = preds-y_test
resids = pd.DataFrame((preds - y_test).reshape(-1))
resids.plot(kind='hist', bins=100, title='Residuals Histogram')
print(resids.describe())
# Out:
#                   0
# count  2.964060e+06
# mean  -8.448159e-04
# std    2.447618e-02
# min   -1.228938e-01
# 25%   -1.778672e-02
# 50%   -7.843128e-04
# 75%    1.618041e-02
# max    1.170180e-01

# %%
print(skew(resids)[0])
print(skewtest(resids))
# Out:
# -0.01692091175380084
# SkewtestResult(statistic=array([-11.89218477]), pvalue=array([1.29961858e-32]))

# %%
comp_ind = 1000
comparison = pd.concat([pd.DataFrame(preds[comp_ind].reshape(-1), columns=['preds']), 
                        pd.DataFrame(y_test[comp_ind].reshape(-1), columns=['true'])], axis=1)
comparison.plot(figsize=(15,10))

# %%
indices = np.random.randint(low=0, high=len(resids_all), size=1)
pd.DataFrame((resids_all[indices])).T.plot(figsize=(15,10), legend=False)

# %%
r2_score(y_test, preds)
# Out:
# 0.7527096087099883

# %% [markdown]
# ## Scaled

# %%
disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-9d2f845a91d7> in <module>
# ----> 1 disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    1937             converters = [StringConverter(dtype, locked=True,
#    1938                                           missing_values=miss, default=fill)
# -> 1939                           for (miss, fill) in zipit]
#    1940     # Update the converters to use the user-defined ones
#    1941     uc_update = []
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1937             converters = [StringConverter(dtype, locked=True,
#    1938                                           missing_values=miss, default=fill)
# -> 1939                           for (miss, fill) in zipit]
#    1940     # Update the converters to use the user-defined ones
#    1941     uc_update = []
#
# ~/venvs/johnny5/lib/python3.7/site-packages/numpy/lib/_iotools.py in __init__(self, dtype_or_func, default, missing_values, locked)
#     698             if isinstance(missing_values, basestring):
#     699                 missing_values = missing_values.split(",")
# --> 700             self.missing_values = set(list(missing_values) + [''])
#     701         #
#     702         self._callingfunction = self._strict_call
#
# KeyboardInterrupt:

# %%
disp_df = pd.DataFrame(disp_raw.T, columns=['disp', 'disp_10noise'])['disp_10noise']

# %%
mean = disp_df.mean()
minimum = disp_df.min()
maximum = disp_df.max()

# %%
scaled_resids = pd.DataFrame(((((resids_all -0.5) * 2.0) * (maximum - minimum)) + mean).reshape(-1))

# %%
scaled_resids.mean()

# %%
scaled_resids.plot(kind='hist', bins=100, figsize=(15,10), title='Errors Histogram for SDOF Problem with 10% Noise')
print('Error Standard Deviation: %E' % scaled_resids.std())
print('Error Mean: %E' % scaled_resids.mean())
