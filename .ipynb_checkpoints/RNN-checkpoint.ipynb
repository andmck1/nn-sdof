# %% [markdown]
# ## Imports

# %%
# File
import pathlib

# %%
# Data
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
# Charting
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Deep Learning
from keras.models import Sequential
from keras.layers import Conv2D, Dropout, MaxPool2D, Dense, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get Data

# %%
# Available files
pathlib.os.listdir('data')
# Out:
# ['acc.csv', 'vel.csv', 'exc.csv', 'disp.csv']

# %%
print('Reading acc')
acc_raw = np.genfromtxt('./data/acc.csv', delimiter=',')
print('Reading vel')
vel_raw = np.genfromtxt('./data/vel.csv', delimiter=',')
print('Reading exc')
exc_raw = np.genfromtxt('./data/exc.csv', delimiter=',')
print('Reading disp')
disp_raw = np.genfromtxt('./data/disp.csv', delimiter=',')
# Out:
# Reading acc
# Reading vel
# Reading exc
# Reading disp

# %%
acc_df = pd.DataFrame(acc_raw.T, columns=['acc','acc_10noise'])
vel_df = pd.DataFrame(vel_raw.T, columns=['vel','vel_10noise'])
exc_df = pd.DataFrame(exc_raw.T, columns=['exc','exc_10noise'])
disp_df = pd.DataFrame(disp_raw.T, columns=['disp','disp_10noise'])

# %%
data = pd.concat([acc_df, vel_df, exc_df, disp_df], axis=1)

# %%
def plot_stacked_timesseries(data, top_col, bottom_col, quantity, top_y_label, bottom_y_label):
    sns.set(style="ticks", color_codes=True)
    plt.subplot(2, 1, 1)
    plt.plot(data.index, data.loc[:, top_col], '.-')
    plt.title(quantity + ' over Time')
    plt.ylabel(top_y_label)

    plt.subplot(2, 1, 2)
    plt.plot(data.index, data.loc[:, bottom_col], '.-')
    plt.xlabel('time (units)')
    plt.ylabel(bottom_y_label)
    plt.show()

# %%
for info in [(acc_df, 'acc', 'acc_10noise', 'Acceleration'), 
             (vel_df, 'vel', 'vel_10noise', 'Velocity'),
             (exc_df, 'exc', 'exc_10noise', 'Excitation'),
             (disp_df, 'disp', 'disp_10noise', 'Displacement')]:
    
    plot_stacked_timesseries(info[0].iloc[:600:10], info[1], info[2],
                             info[3], 'No noise','10% Noise?')

# %% [markdown]
# ## Preprocessing

# %%
no_noise_data = data.loc[:, [x for x in data.columns if 'noise' not in x]]
noise_data = data.loc[:, [x for x in data.columns if 'noise' in x]]

# %%
input_scaled = pd.DataFrame()
for col in no_noise_data.columns:
    mean = no_noise_data[col].mean()
    minimum = no_noise_data[col].min()
    maximum = no_noise_data[col].max()
    input_scaled[col] = (no_noise_data[col]-mean)/(maximum - minimum)
    input_scaled[col] = input_scaled[col] / 2.0 + 0.5
    
noise_input_scaled = pd.DataFrame()
for col in noise_data.columns:
    mean = noise_data[col].mean()
    minimum = noise_data[col].min()
    maximum = noise_data[col].max()
    noise_input_scaled[col] = (noise_data[col]-mean)/(maximum - minimum)
    noise_input_scaled[col] = noise_input_scaled[col] / 2.0 + 0.5

# %%
input_data_scaled = input_scaled.drop('disp',axis=1)
output_data_scaled = input_scaled['disp']

noise_input_data_scaled = noise_input_scaled.drop('disp_10noise',axis=1)
noise_output_data_scaled = noise_input_scaled['disp_10noise']

# %%
input_data_scaled.head()
# Out:
#         acc       vel       exc
# 0  0.540818  0.500000  0.540522
# 1  0.474899  0.505608  0.476769
# 2  0.547336  0.513542  0.551074
# 3  0.541087  0.545093  0.554383
# 4  0.456274  0.544150  0.470235

# %%
n_features = 10
data_cols = input_data_scaled.columns
col = 'acc'
feature_cols = []
for i in range(0,n_features):
    feature_cols.append(str(col) + '_t-' + str(i))
df = pd.DataFrame(columns=feature_cols, index=input_data_scaled.index)

# %%
output_values = output_data_scaled.values

input_values_list = []
for col in input_data_scaled:
    input_values_list.append(TimeseriesGenerator(input_data_scaled[col].values, output_data_scaled, 
                                                 length=100)[0][0].reshape(1,128,100))
input_values = np.append(input_values_list[0], input_values_list[1], axis=0)
for arr in input_values_list[2:]:
    input_values = np.append(input_values, arr, axis=0)

# %%
# acc_rnn = input_data_scaled['acc'].values
vel_rnn = input_data_scaled['vel'].values
# exc_rnn = input_data_scaled['exc'].values
disp_rnn = output_data_scaled.values

# %%
o = TimeseriesGenerator(acc_rnn, disp_rnn, length=100)[0][0]
o2 = TimeseriesGenerator(vel_rnn, disp_rnn, length=100)[0][0]

# %%
np.append(o.reshape(1,128,100), o2.reshape(1,128,100), axis=0)
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
test_i = input_data_scaled['acc'].head(20).values
test_o = output_data_scaled.head(20).values

# %%
TimeseriesGenerator(test_i,test_o, 10)[0]
# Out:
# (array([[0.54081791, 0.47489851, 0.54733591, 0.54108708, 0.45627353,
#          0.53306614, 0.44897023, 0.48432114, 0.49672031, 0.51191535],
#         [0.47489851, 0.54733591, 0.54108708, 0.45627353, 0.53306614,
#          0.44897023, 0.48432114, 0.49672031, 0.51191535, 0.40514151],
#         [0.54733591, 0.54108708, 0.45627353, 0.53306614, 0.44897023,
#          0.48432114, 0.49672031, 0.51191535, 0.40514151, 0.50433211],
#         [0.54108708, 0.45627353, 0.53306614, 0.44897023, 0.48432114,
#          0.49672031, 0.51191535, 0.40514151, 0.50433211, 0.53479133],
#         [0.45627353, 0.53306614, 0.44897023, 0.48432114, 0.49672031,
#          0.51191535, 0.40514151, 0.50433211, 0.53479133, 0.57583346],
#         [0.53306614, 0.44897023, 0.48432114, 0.49672031, 0.51191535,
#          0.40514151, 0.50433211, 0.53479133, 0.57583346, 0.42327259],
#         [0.44897023, 0.48432114, 0.49672031, 0.51191535, 0.40514151,
#          0.50433211, 0.53479133, 0.57583346, 0.42327259, 0.54403962],
#         [0.48432114, 0.49672031, 0.51191535, 0.40514151, 0.50433211,
#          0.53479133, 0.57583346, 0.42327259, 0.54403962, 0.49098583],
#         [0.49672031, 0.51191535, 0.40514151, 0.50433211, 0.53479133,
#          0.57583346, 0.42327259, 0.54403962, 0.49098583, 0.45831581],
#         [0.51191535, 0.40514151, 0.50433211, 0.53479133, 0.57583346,
#          0.42327259, 0.54403962, 0.49098583, 0.45831581, 0.48692745]]),
#  array([0.51261466, 0.51003707, 0.50685775, 0.50543097, 0.50528826,
#         0.50475258, 0.50424418, 0.50355238, 0.50162645, 0.49896783]))

# %%
input_vals = input_data_scaled.values.reshape(-1,100,3,1)
output_vals = output_data_scaled.values.reshape(-1,100)

noise_input_vals = noise_input_data_scaled.values.reshape(-1,100,3,1)
noise_output_vals = noise_output_data_scaled.values.reshape(-1,100)

# %% [markdown]
# ## Model

# %%
def run_and_results(X_train, X_test, y_train, y_test):
    
    # Model
    model = Sequential()

    # -- INPUT
    model.add(Conv2D(3, (9,3), padding='same', input_shape=X_train[0].shape, activation='relu'))
    # model.add(MaxPool2D(pool_size=(1,2)))

    # -- HIDDEN
    model.add(Conv2D(8, (15,1), activation='relu'))
    model.add(MaxPool2D(pool_size=(2,2)))
    model.add(Dropout(0.33))


    model.add(Flatten())
    model.add(Dense(500, activation='relu'))

    # -- OUTPUT
    model.add(Dense(100))


    # Prepare model for training
    model.compile(loss='mse',
                  optimizer='adam',
                  metrics=['mae'])

    # -- SUMMARY
    print(model.summary())
    
    # Fit model
    history = model.fit(X_train, y_train,
                        batch_size=5000,
                        epochs=700,
                        verbose=True,
                        validation_data=(X_test, y_test))
    
    # Scores
    print(model.evaluate(X_test, y_test, verbose=0))
    
    # Error plot (%)
    preds = model.predict(X_test)
    resids = pd.DataFrame(((preds - y_test)/y_test).reshape(-1))  * 100
    resids.plot(kind='hist', bins=100, title='% Residuals Histogram')
    print(resids.describe())
    
    # Prediction plots
    full_preds = pd.DataFrame(model.predict(input_data_scaled.values.reshape(-1,100,3,1)).reshape(-1), columns=['Preds'])
    full_preds = (full_preds - 0.5) * 2.0 * (no_noise_data['disp'].max()-no_noise_data['disp'].min()) + no_noise_data['disp'].mean()

    plt.figure(figsize=(15,6))

    min_index = 0
    max_index = 300
    top = full_preds[min_index:max_index]
    middle = no_noise_data['disp'][min_index:max_index]
    bottom = full_preds[min_index:max_index].subtract(no_noise_data['disp'][min_index:max_index],axis='index')

    sns.set(style="ticks", color_codes=True)

    plt.title('Displacement over Time')

    plt.subplot(3, 1, 1)
    plt.plot(middle.index, middle, '.-')
    plt.ylabel('Actl Disp')

    plt.subplot(3, 1, 2)
    plt.plot(top.index, top, '.-')
    plt.ylabel('Pred Disp')

    plt.subplot(3, 1, 3)
    plt.plot(bottom.index, bottom, '.-')
    plt.ylabel('Residuals')

    plt.xlabel('time (units)')
    plt.show()
    
    results = full_preds.join(no_noise_data['disp'])
    results[:2000].plot(figsize=(15,6))

# %%
# Data
X_train, X_test, y_train, y_test = train_test_split(noise_input_vals, noise_output_vals, test_size=0.3, random_state=42)

# Run and results
run_and_results(X_train, X_test, y_train, y_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_294 (Conv2D)          (None, 100, 3, 3)         84
# _________________________________________________________________
# conv2d_295 (Conv2D)          (None, 86, 3, 8)          368
# _________________________________________________________________
# max_pooling2d_90 (MaxPooling (None, 43, 1, 8)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 43, 1, 8)          0
# _________________________________________________________________
# flatten_74 (Flatten)         (None, 344)               0
# _________________________________________________________________
# dense_148 (Dense)            (None, 500)               172500
# _________________________________________________________________
# dense_149 (Dense)            (None, 100)               50100
# =================================================================
# Total params: 223,052
# Trainable params: 223,052
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 11620 samples, validate on 4980 samples
# Epoch 1/700
# 11620/11620 [==============================] - 2s 193us/step - loss: 0.2191 - mean_absolute_error: 0.4586 - val_loss: 0.1227 - val_mean_absolute_error: 0.3359
# Epoch 2/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0893 - mean_absolute_error: 0.2665 - val_loss: 0.0271 - val_mean_absolute_error: 0.1320
# Epoch 3/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0404 - mean_absolute_error: 0.1657 - val_loss: 0.0202 - val_mean_absolute_error: 0.1267
# Epoch 4/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0189 - mean_absolute_error: 0.1117 - val_loss: 0.0073 - val_mean_absolute_error: 0.0684
# Epoch 5/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0133 - mean_absolute_error: 0.0928 - val_loss: 0.0198 - val_mean_absolute_error: 0.1215
# Epoch 6/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0203 - mean_absolute_error: 0.1199 - val_loss: 0.0129 - val_mean_absolute_error: 0.0962
# Epoch 7/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0128 - mean_absolute_error: 0.0924 - val_loss: 0.0063 - val_mean_absolute_error: 0.0624
# Epoch 8/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0098 - mean_absolute_error: 0.0786 - val_loss: 0.0060 - val_mean_absolute_error: 0.0621
# Epoch 9/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0085 - mean_absolute_error: 0.0738 - val_loss: 0.0027 - val_mean_absolute_error: 0.0413
# Epoch 10/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0054 - mean_absolute_error: 0.0587 - val_loss: 0.0043 - val_mean_absolute_error: 0.0528
# Epoch 11/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0065 - mean_absolute_error: 0.0644 - val_loss: 0.0044 - val_mean_absolute_error: 0.0535
# Epoch 12/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0060 - mean_absolute_error: 0.0617 - val_loss: 0.0029 - val_mean_absolute_error: 0.0429
# Epoch 13/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0053 - mean_absolute_error: 0.0581 - val_loss: 0.0029 - val_mean_absolute_error: 0.0426
# Epoch 14/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0053 - mean_absolute_error: 0.0582 - val_loss: 0.0023 - val_mean_absolute_error: 0.0381
# Epoch 15/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0045 - mean_absolute_error: 0.0533 - val_loss: 0.0026 - val_mean_absolute_error: 0.0408
# Epoch 16/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0046 - mean_absolute_error: 0.0539 - val_loss: 0.0026 - val_mean_absolute_error: 0.0407
# Epoch 17/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0043 - mean_absolute_error: 0.0524 - val_loss: 0.0021 - val_mean_absolute_error: 0.0368
# Epoch 18/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0042 - mean_absolute_error: 0.0516 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 19/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0042 - mean_absolute_error: 0.0518 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 20/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0040 - mean_absolute_error: 0.0504 - val_loss: 0.0023 - val_mean_absolute_error: 0.0380
# Epoch 21/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0041 - mean_absolute_error: 0.0507 - val_loss: 0.0022 - val_mean_absolute_error: 0.0369
# Epoch 22/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0039 - mean_absolute_error: 0.0498 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356
# Epoch 23/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0039 - mean_absolute_error: 0.0497 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 24/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0038 - mean_absolute_error: 0.0490 - val_loss: 0.0021 - val_mean_absolute_error: 0.0362
# Epoch 25/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0038 - mean_absolute_error: 0.0490 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 26/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0037 - mean_absolute_error: 0.0485 - val_loss: 0.0020 - val_mean_absolute_error: 0.0357
# Epoch 27/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0037 - mean_absolute_error: 0.0484 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 28/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0036 - mean_absolute_error: 0.0480 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 29/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0036 - mean_absolute_error: 0.0478 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 30/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0036 - mean_absolute_error: 0.0475 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 31/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0036 - mean_absolute_error: 0.0475 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 32/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0035 - mean_absolute_error: 0.0472 - val_loss: 0.0020 - val_mean_absolute_error: 0.0357
# Epoch 33/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0035 - mean_absolute_error: 0.0469 - val_loss: 0.0020 - val_mean_absolute_error: 0.0358
# Epoch 34/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0034 - mean_absolute_error: 0.0466 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356
# Epoch 35/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0034 - mean_absolute_error: 0.0467 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 36/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0034 - mean_absolute_error: 0.0463 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 37/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0034 - mean_absolute_error: 0.0462 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 38/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0033 - mean_absolute_error: 0.0460 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 39/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0033 - mean_absolute_error: 0.0456 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 40/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0033 - mean_absolute_error: 0.0457 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 41/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0033 - mean_absolute_error: 0.0455 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 42/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0033 - mean_absolute_error: 0.0455 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 43/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0032 - mean_absolute_error: 0.0452 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 44/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0032 - mean_absolute_error: 0.0449 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 45/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0032 - mean_absolute_error: 0.0448 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 46/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0031 - mean_absolute_error: 0.0444 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 47/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0031 - mean_absolute_error: 0.0445 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 48/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0031 - mean_absolute_error: 0.0443 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 49/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0031 - mean_absolute_error: 0.0441 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 50/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0031 - mean_absolute_error: 0.0440 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 51/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0030 - mean_absolute_error: 0.0435 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 52/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0030 - mean_absolute_error: 0.0434 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 53/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0029 - mean_absolute_error: 0.0431 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 54/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0029 - mean_absolute_error: 0.0429 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 55/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0029 - mean_absolute_error: 0.0427 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352
# Epoch 56/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0029 - mean_absolute_error: 0.0425 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352
# Epoch 57/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0028 - mean_absolute_error: 0.0423 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 58/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0028 - mean_absolute_error: 0.0423 - val_loss: 0.0020 - val_mean_absolute_error: 0.0351
# Epoch 59/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0028 - mean_absolute_error: 0.0421 - val_loss: 0.0020 - val_mean_absolute_error: 0.0354
# Epoch 60/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0027 - mean_absolute_error: 0.0417 - val_loss: 0.0020 - val_mean_absolute_error: 0.0350
# Epoch 61/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0027 - mean_absolute_error: 0.0415 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 62/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0027 - mean_absolute_error: 0.0414 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 63/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0027 - mean_absolute_error: 0.0415 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 64/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0027 - mean_absolute_error: 0.0412 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 65/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0026 - mean_absolute_error: 0.0410 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352
# Epoch 66/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0026 - mean_absolute_error: 0.0408 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 67/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0026 - mean_absolute_error: 0.0406 - val_loss: 0.0020 - val_mean_absolute_error: 0.0352
# Epoch 68/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0026 - mean_absolute_error: 0.0406 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 69/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0026 - mean_absolute_error: 0.0405 - val_loss: 0.0020 - val_mean_absolute_error: 0.0353
# Epoch 70/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 71/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0402 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 72/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0400 - val_loss: 0.0019 - val_mean_absolute_error: 0.0350
# Epoch 73/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0399 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 74/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0396 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 75/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0397 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 76/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0397 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 77/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0025 - mean_absolute_error: 0.0395 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 78/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0394 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 79/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0392 - val_loss: 0.0020 - val_mean_absolute_error: 0.0351
# Epoch 80/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0392 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 81/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0392 - val_loss: 0.0019 - val_mean_absolute_error: 0.0349
# Epoch 82/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0390 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 83/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0390 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 84/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0387 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 85/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0024 - mean_absolute_error: 0.0386 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 86/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0385 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 87/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0384 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 88/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0382 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 89/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0383 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 90/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0381 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 91/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0382 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 92/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0380 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 93/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0379 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 94/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0023 - mean_absolute_error: 0.0378 - val_loss: 0.0019 - val_mean_absolute_error: 0.0347
# Epoch 95/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0377 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 96/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0376 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 97/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0376 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 98/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0375 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 99/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0374 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 100/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0373 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 101/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0372 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 102/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0372 - val_loss: 0.0019 - val_mean_absolute_error: 0.0343
# Epoch 103/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0370 - val_loss: 0.0019 - val_mean_absolute_error: 0.0343
# Epoch 104/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0022 - mean_absolute_error: 0.0370 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 105/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0369 - val_loss: 0.0019 - val_mean_absolute_error: 0.0343
# Epoch 106/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0367 - val_loss: 0.0019 - val_mean_absolute_error: 0.0342
# Epoch 107/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0368 - val_loss: 0.0019 - val_mean_absolute_error: 0.0344
# Epoch 108/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0366 - val_loss: 0.0019 - val_mean_absolute_error: 0.0342
# Epoch 109/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0366 - val_loss: 0.0019 - val_mean_absolute_error: 0.0343
# Epoch 110/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0365 - val_loss: 0.0019 - val_mean_absolute_error: 0.0341
# Epoch 111/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0364 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 112/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0364 - val_loss: 0.0019 - val_mean_absolute_error: 0.0342
# Epoch 113/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0363 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 114/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0363 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 115/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0362 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 116/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 117/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0360 - val_loss: 0.0018 - val_mean_absolute_error: 0.0341
# Epoch 118/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0021 - mean_absolute_error: 0.0361 - val_loss: 0.0018 - val_mean_absolute_error: 0.0339
# Epoch 119/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0360 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 120/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0359 - val_loss: 0.0018 - val_mean_absolute_error: 0.0339
# Epoch 121/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0357 - val_loss: 0.0018 - val_mean_absolute_error: 0.0339
# Epoch 122/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0358 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 123/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0357 - val_loss: 0.0018 - val_mean_absolute_error: 0.0338
# Epoch 124/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0356 - val_loss: 0.0018 - val_mean_absolute_error: 0.0337
# Epoch 125/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0354 - val_loss: 0.0018 - val_mean_absolute_error: 0.0337
# Epoch 126/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0355 - val_loss: 0.0018 - val_mean_absolute_error: 0.0337
# Epoch 127/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 128/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0353 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 129/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 130/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 131/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0350 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 132/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0350 - val_loss: 0.0018 - val_mean_absolute_error: 0.0334
# Epoch 133/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0350 - val_loss: 0.0018 - val_mean_absolute_error: 0.0334
# Epoch 134/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0349 - val_loss: 0.0018 - val_mean_absolute_error: 0.0334
# Epoch 135/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0349 - val_loss: 0.0018 - val_mean_absolute_error: 0.0333
# Epoch 136/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0347 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 137/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0347 - val_loss: 0.0018 - val_mean_absolute_error: 0.0335
# Epoch 138/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0347 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 139/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0346 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 140/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0346 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 141/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 142/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0344 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 143/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0343 - val_loss: 0.0017 - val_mean_absolute_error: 0.0329
# Epoch 144/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0019 - mean_absolute_error: 0.0342 - val_loss: 0.0017 - val_mean_absolute_error: 0.0329
# Epoch 145/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0341 - val_loss: 0.0017 - val_mean_absolute_error: 0.0328
# Epoch 146/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0340 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 147/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0340 - val_loss: 0.0017 - val_mean_absolute_error: 0.0327
# Epoch 148/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0339 - val_loss: 0.0017 - val_mean_absolute_error: 0.0326
# Epoch 149/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0338 - val_loss: 0.0017 - val_mean_absolute_error: 0.0326
# Epoch 150/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0338 - val_loss: 0.0017 - val_mean_absolute_error: 0.0325
# Epoch 151/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0338 - val_loss: 0.0017 - val_mean_absolute_error: 0.0324
# Epoch 152/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0338 - val_loss: 0.0017 - val_mean_absolute_error: 0.0324
# Epoch 153/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0336 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 154/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0335 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 155/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0335 - val_loss: 0.0016 - val_mean_absolute_error: 0.0322
# Epoch 156/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0335 - val_loss: 0.0017 - val_mean_absolute_error: 0.0323
# Epoch 157/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0334 - val_loss: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 158/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0018 - mean_absolute_error: 0.0333 - val_loss: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 159/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0332 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 160/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0332 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 161/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0331 - val_loss: 0.0016 - val_mean_absolute_error: 0.0318
# Epoch 162/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0330 - val_loss: 0.0016 - val_mean_absolute_error: 0.0317
# Epoch 163/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0330 - val_loss: 0.0016 - val_mean_absolute_error: 0.0316
# Epoch 164/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0328 - val_loss: 0.0016 - val_mean_absolute_error: 0.0316
# Epoch 165/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0329 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 166/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0327 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 167/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0327 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 168/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0326 - val_loss: 0.0016 - val_mean_absolute_error: 0.0313
# Epoch 169/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0325 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 170/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0326 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 171/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0324 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 172/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0015 - val_mean_absolute_error: 0.0310
# Epoch 173/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0015 - val_mean_absolute_error: 0.0310
# Epoch 174/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0017 - mean_absolute_error: 0.0323 - val_loss: 0.0015 - val_mean_absolute_error: 0.0309
# Epoch 175/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0321 - val_loss: 0.0015 - val_mean_absolute_error: 0.0308
# Epoch 176/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0321 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 177/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0320 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 178/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0319 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 179/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0318 - val_loss: 0.0015 - val_mean_absolute_error: 0.0305
# Epoch 180/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0318 - val_loss: 0.0015 - val_mean_absolute_error: 0.0305
# Epoch 181/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0317 - val_loss: 0.0015 - val_mean_absolute_error: 0.0303
# Epoch 182/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0317 - val_loss: 0.0015 - val_mean_absolute_error: 0.0303
# Epoch 183/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0316 - val_loss: 0.0015 - val_mean_absolute_error: 0.0302
# Epoch 184/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0316 - val_loss: 0.0014 - val_mean_absolute_error: 0.0301
# Epoch 185/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0315 - val_loss: 0.0014 - val_mean_absolute_error: 0.0301
# Epoch 186/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0314 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300
# Epoch 187/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0016 - mean_absolute_error: 0.0313 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 188/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0312 - val_loss: 0.0014 - val_mean_absolute_error: 0.0298
# Epoch 189/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0311 - val_loss: 0.0014 - val_mean_absolute_error: 0.0298
# Epoch 190/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0312 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 191/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0311 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 192/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0310 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 193/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0310 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 194/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0309 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 195/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0308 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 196/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0308 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 197/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0308 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 198/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0292
# Epoch 199/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0306 - val_loss: 0.0014 - val_mean_absolute_error: 0.0292
# Epoch 200/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0306 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 201/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0305 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 202/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0304 - val_loss: 0.0013 - val_mean_absolute_error: 0.0289
# Epoch 203/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0303 - val_loss: 0.0013 - val_mean_absolute_error: 0.0288
# Epoch 204/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0015 - mean_absolute_error: 0.0304 - val_loss: 0.0013 - val_mean_absolute_error: 0.0288
# Epoch 205/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0302 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 206/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0301 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 207/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0302 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 208/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0301 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 209/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0300 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 210/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0300 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 211/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0299 - val_loss: 0.0013 - val_mean_absolute_error: 0.0283
# Epoch 212/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0297 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 213/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0297 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 214/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0296 - val_loss: 0.0013 - val_mean_absolute_error: 0.0281
# Epoch 215/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0295 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 216/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 217/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 0.0012 - val_mean_absolute_error: 0.0279
# Epoch 218/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0293 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 219/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0293 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 220/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0014 - mean_absolute_error: 0.0292 - val_loss: 0.0012 - val_mean_absolute_error: 0.0277
# Epoch 221/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0292 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 222/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0291 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 223/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0291 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 224/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0290 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 225/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0289 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 226/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0289 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 227/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0289 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 228/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0287 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 229/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0288 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 230/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0287 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 231/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0287 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 232/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0286 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 233/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0286 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 234/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0285 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 235/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0285 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 236/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 237/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0269
# Epoch 238/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 239/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 240/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 241/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 242/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 243/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 244/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0013 - mean_absolute_error: 0.0281 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 245/700
# 11620/11620 [==============================] - 0s 5us/step - loss: 0.0012 - mean_absolute_error: 0.0280 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 246/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0280 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 247/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0281 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 248/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0280 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 249/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 250/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 251/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 252/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 253/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 254/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0278 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 255/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0278 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 256/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0278 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 257/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0277 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 258/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0277 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 259/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0277 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 260/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0277 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 261/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0277 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 262/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0276 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 263/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0276 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 264/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0276 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 265/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0276 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 266/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 267/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 268/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0275 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 269/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0274 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 270/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0274 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 271/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0274 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 272/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 273/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0012 - mean_absolute_error: 0.0273 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 274/700
# ...
# Epoch 611/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8456e-04 - val_mean_absolute_error: 0.0248
# Epoch 612/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8503e-04 - val_mean_absolute_error: 0.0249
# Epoch 613/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8548e-04 - val_mean_absolute_error: 0.0249
# Epoch 614/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8314e-04 - val_mean_absolute_error: 0.0248
# Epoch 615/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8255e-04 - val_mean_absolute_error: 0.0248
# Epoch 616/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8471e-04 - val_mean_absolute_error: 0.0249
# Epoch 617/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8423e-04 - val_mean_absolute_error: 0.0248
# Epoch 618/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8119e-04 - val_mean_absolute_error: 0.0248
# Epoch 619/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8451e-04 - val_mean_absolute_error: 0.0248
# Epoch 620/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8103e-04 - val_mean_absolute_error: 0.0248
# Epoch 621/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8150e-04 - val_mean_absolute_error: 0.0248
# Epoch 622/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8111e-04 - val_mean_absolute_error: 0.0248
# Epoch 623/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8082e-04 - val_mean_absolute_error: 0.0248
# Epoch 624/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8010e-04 - val_mean_absolute_error: 0.0248
# Epoch 625/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8072e-04 - val_mean_absolute_error: 0.0248
# Epoch 626/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8032e-04 - val_mean_absolute_error: 0.0248
# Epoch 627/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8258e-04 - val_mean_absolute_error: 0.0248
# Epoch 628/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8021e-04 - val_mean_absolute_error: 0.0248
# Epoch 629/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8044e-04 - val_mean_absolute_error: 0.0248
# Epoch 630/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8231e-04 - val_mean_absolute_error: 0.0248
# Epoch 631/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8174e-04 - val_mean_absolute_error: 0.0248
# Epoch 632/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8542e-04 - val_mean_absolute_error: 0.0249
# Epoch 633/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8011e-04 - val_mean_absolute_error: 0.0248
# Epoch 634/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8198e-04 - val_mean_absolute_error: 0.0248
# Epoch 635/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8174e-04 - val_mean_absolute_error: 0.0248
# Epoch 636/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8205e-04 - val_mean_absolute_error: 0.0248
# Epoch 637/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8250e-04 - val_mean_absolute_error: 0.0248
# Epoch 638/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7909e-04 - val_mean_absolute_error: 0.0248
# Epoch 639/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8014e-04 - val_mean_absolute_error: 0.0248
# Epoch 640/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8284e-04 - val_mean_absolute_error: 0.0248
# Epoch 641/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7995e-04 - val_mean_absolute_error: 0.0248
# Epoch 642/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8695e-04 - val_mean_absolute_error: 0.0249
# Epoch 643/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8389e-04 - val_mean_absolute_error: 0.0248
# Epoch 644/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8219e-04 - val_mean_absolute_error: 0.0248
# Epoch 645/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8246e-04 - val_mean_absolute_error: 0.0248
# Epoch 646/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8131e-04 - val_mean_absolute_error: 0.0248
# Epoch 647/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.8150e-04 - val_mean_absolute_error: 0.0248
# Epoch 648/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.7953e-04 - val_mean_absolute_error: 0.0248
# Epoch 649/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7858e-04 - val_mean_absolute_error: 0.0248
# Epoch 650/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8014e-04 - val_mean_absolute_error: 0.0248
# Epoch 651/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8009e-04 - val_mean_absolute_error: 0.0248
# Epoch 652/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7961e-04 - val_mean_absolute_error: 0.0248
# Epoch 653/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8393e-04 - val_mean_absolute_error: 0.0249
# Epoch 654/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7904e-04 - val_mean_absolute_error: 0.0248
# Epoch 655/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.7920e-04 - val_mean_absolute_error: 0.0248
# Epoch 656/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7953e-04 - val_mean_absolute_error: 0.0248
# Epoch 657/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7695e-04 - val_mean_absolute_error: 0.0248
# Epoch 658/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7809e-04 - val_mean_absolute_error: 0.0248
# Epoch 659/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7700e-04 - val_mean_absolute_error: 0.0248
# Epoch 660/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8213e-04 - val_mean_absolute_error: 0.0248
# Epoch 661/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8057e-04 - val_mean_absolute_error: 0.0248
# Epoch 662/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7768e-04 - val_mean_absolute_error: 0.0248
# Epoch 663/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7958e-04 - val_mean_absolute_error: 0.0248
# Epoch 664/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7776e-04 - val_mean_absolute_error: 0.0248
# Epoch 665/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7817e-04 - val_mean_absolute_error: 0.0248
# Epoch 666/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7869e-04 - val_mean_absolute_error: 0.0248
# Epoch 667/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7789e-04 - val_mean_absolute_error: 0.0248
# Epoch 668/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7643e-04 - val_mean_absolute_error: 0.0248
# Epoch 669/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7808e-04 - val_mean_absolute_error: 0.0248
# Epoch 670/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7659e-04 - val_mean_absolute_error: 0.0248
# Epoch 671/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7798e-04 - val_mean_absolute_error: 0.0248
# Epoch 672/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7767e-04 - val_mean_absolute_error: 0.0248
# Epoch 673/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7695e-04 - val_mean_absolute_error: 0.0248
# Epoch 674/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.8116e-04 - val_mean_absolute_error: 0.0248
# Epoch 675/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7769e-04 - val_mean_absolute_error: 0.0248
# Epoch 676/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 9.7834e-04 - val_mean_absolute_error: 0.0248
# Epoch 677/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7609e-04 - val_mean_absolute_error: 0.0248
# Epoch 678/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7593e-04 - val_mean_absolute_error: 0.0248
# Epoch 679/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7740e-04 - val_mean_absolute_error: 0.0248
# Epoch 680/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7562e-04 - val_mean_absolute_error: 0.0247
# Epoch 681/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7615e-04 - val_mean_absolute_error: 0.0248
# Epoch 682/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7516e-04 - val_mean_absolute_error: 0.0247
# Epoch 683/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7545e-04 - val_mean_absolute_error: 0.0247
# Epoch 684/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7535e-04 - val_mean_absolute_error: 0.0247
# Epoch 685/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7585e-04 - val_mean_absolute_error: 0.0247
# Epoch 686/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7535e-04 - val_mean_absolute_error: 0.0247
# Epoch 687/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7654e-04 - val_mean_absolute_error: 0.0248
# Epoch 688/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7461e-04 - val_mean_absolute_error: 0.0247
# Epoch 689/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7516e-04 - val_mean_absolute_error: 0.0247
# Epoch 690/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7557e-04 - val_mean_absolute_error: 0.0247
# Epoch 691/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7405e-04 - val_mean_absolute_error: 0.0247
# Epoch 692/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7873e-04 - val_mean_absolute_error: 0.0248
# Epoch 693/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7505e-04 - val_mean_absolute_error: 0.0247
# Epoch 694/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7777e-04 - val_mean_absolute_error: 0.0248
# Epoch 695/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7508e-04 - val_mean_absolute_error: 0.0247
# Epoch 696/700
# 11620/11620 [==============================] - 0s 6us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7369e-04 - val_mean_absolute_error: 0.0247
# Epoch 697/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7664e-04 - val_mean_absolute_error: 0.0248
# Epoch 698/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7375e-04 - val_mean_absolute_error: 0.0247
# Epoch 699/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0252 - val_loss: 9.7439e-04 - val_mean_absolute_error: 0.0247
# Epoch 700/700
# 11620/11620 [==============================] - 0s 7us/step - loss: 0.0010 - mean_absolute_error: 0.0253 - val_loss: 9.7455e-04 - val_mean_absolute_error: 0.0247
# [0.0009745468192894656, 0.024723061162185478]
#                    0
# count  498000.000000
# mean        0.580901
# std         6.416014
# min       -21.411587
# 25%        -3.794101
# 50%         0.141700
# 75%         4.484808
# max        52.024933
